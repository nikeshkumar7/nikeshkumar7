# %% [markdown]
# <a href="https://colab.research.google.com/github/nikeshkumar7/colab/blob/main/unsharp%20masking%20technique.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import cv2
import matplotlib.pyplot as plt
import os
import numpy as np
# Out:
# Mounted at /content/drive

# %%
img=cv2.imread('/content/hanuman.jpeg')
plt.imshow(img)
plt.show()

# %%
blurred = cv2.GaussianBlur(img, (5, 5), 0)

# %%
mask = cv2.subtract(img, blurred)

# %%
img_sharp = cv2.add(img, mask)

# %%
plt.imshow(cv2.cvtColor(img_sharp, cv2.COLOR_BGR2RGB))
plt.title('Sharpened Image')
plt.show()
