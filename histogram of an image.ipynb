# %% [markdown]
# <a href="https://colab.research.google.com/github/nikeshkumar7/colab/blob/main/histogram%20of%20an%20image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import cv2
import matplotlib.pyplot as plt
import os
import numpy as np
# Out:
# Mounted at /content/drive

# %%
input_image = cv2.imread('/content/mata.jpeg', cv2.IMREAD_GRAYSCALE)

# %%
histogram = cv2.calcHist([input_image], [0], None, [256], [0, 256])

# %%
plt.figure(figsize=(8, 6))
plt.title('Histogram of the Image')
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.plot(histogram)
plt.xlim([0, 256])
plt.show()
