# %% [markdown]
# <a href="https://colab.research.google.com/github/nikeshkumar7/colab/blob/main/mini_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random


responses = {
    "hello": ["Hello!", "Hi there!", "Hey!"],
    "how are you": ["I'm good, thanks!", "I'm just a computer program, but I'm here to help."],
    "bye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I don't understand that.", "Could you please rephrase that?", "I'm still learning."],
}


def get_response(input_text):
    input_text = input_text.lower()
    for key, value in responses.items():
        if key in input_text:
            return random.choice(value)
    return random.choice(responses["default"])


while True:
    user_input = input("You: ")
    if user_input.lower() == "exit":
        print("AI Assistant: Goodbye!")
        break
    response = get_response(user_input)
    print("AI Assistant:", response)
