# %% [markdown]
# <a href="https://colab.research.google.com/github/nikeshkumar7/colab/blob/main/image_import.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import cv2
import matplotlib.pyplot as plt
import os
import numpy as np
# Out:
# Mounted at /content/drive

# %%
img=cv2.imread('/content/download.jpeg')
plt.imshow(img)
plt.show()

# %%
print (img.shape)
# Out:
# (272, 186, 3)

# %%
rimg=cv2.resize(img,(156,156))
plt.imshow(rimg)
plt.show()

# %%
path='/content/drive/MyDrive'
cv2.imwrite(os.path.join(path,'resize_krishna.jpg'),rimg)
cv2.waitKey(0)
print(rimg.shape)
# Out:
# (156, 156, 3)

# %%
print(img)
# Out:
# [[[253 252 254]
#   [253 252 254]
#   [251 253 254]
#   ...
#   [236 253 255]
#   [236 253 255]
#   [236 253 255]]
#
#  [[253 252 254]
#   [253 252 254]
#   [251 253 254]
#   ...
#   [236 253 255]
#   [236 253 255]
#   [236 253 255]]
#
#  [[251 253 254]
#   [251 253 254]
#   [251 253 254]
#   ...
#   [234 253 255]
#   [236 253 255]
#   [236 253 255]]
#
#  ...
#
#  [[128 104  92]
#   [128 104  92]
#   [128 104  92]
#   ...
#   [235 230 229]
#   [233 228 227]
#   [233 228 227]]
#
#  [[122  98  86]
#   [122  98  86]
#   [121  97  85]
#   ...
#   [234 229 228]
#   [233 228 227]
#   [233 228 227]]
#
#  [[118  94  82]
#   [117  93  81]
#   [117  93  81]
#   ...
#   [234 229 228]
#   [233 228 227]
#   [233 228 227]]]

# %%
cv2.cvtColor(rimg, cv2.COLOR_BGR2RGB)
# Out:
# array([[[254, 252, 253],
#         [254, 252, 252],
#         [254, 253, 251],
#         ...,
#         [255, 253, 236],
#         [255, 253, 236],
#         [255, 253, 236]],
#
#        [[254, 253, 251],
#         [254, 253, 251],
#         [254, 253, 251],
#         ...,
#         [255, 253, 234],
#         [255, 253, 235],
#         [255, 253, 236]],
#
#        [[254, 253, 251],
#         [254, 253, 251],
#         [254, 253, 251],
#         ...,
#         [255, 253, 234],
#         [255, 253, 234],
#         [255, 253, 234]],
#
#        ...,
#
#        [[104, 116, 140],
#         [104, 116, 140],
#         [105, 118, 141],
#         ...,
#         [230, 231, 236],
#         [229, 230, 235],
#         [229, 230, 235]],
#
#        [[ 93, 105, 129],
#         [ 93, 105, 129],
#         [ 93, 105, 129],
#         ...,
#         [229, 230, 235],
#         [228, 228, 233],
#         [227, 228, 233]],
#
#        [[ 83,  95, 119],
#         [ 83,  95, 119],
#         [ 82,  94, 118],
# ...

# %%
cimg=cv2.cvtColor(rimg,cv2.COLOR_BGR2RGB)
plt.imshow(cimg)

# %%
img_pad=cv2.copyMakeBorder(cimg,50,50,50,50,cv2.BORDER_CONSTANT,value=(0,0,0))
plt.imshow(img_pad)
