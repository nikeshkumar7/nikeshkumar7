# %% [markdown]
# <a href="https://colab.research.google.com/github/nikeshkumar7/colab/blob/main/arithmatic_operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import cv2
import matplotlib.pyplot as plt
import os
import numpy as np
# Out:
# Mounted at /content/drive

# %%
img1 = cv2.imread('/content/1-500x250-3.jpg')
img2 = cv2.imread('/content/2-500x250-2.jpg')

# %%
plt.imshow(img1)
plt.show()

# %%
plt.imshow(img2)
plt.show()

# %%
weightedSum = cv2.addWeighted(img1, 0.5, img2, 0.4, 0)

# %%
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()

# %%
plt.imshow(weightedSum)
plt.show()

# %%
img3 = cv2.imread('/content/star-1-300x168.jpg')
img4 = cv2.imread('/content/dot-300x168.jpg')

# %%
plt.imshow(img3)
plt.show()

# %%
plt.imshow(img4)
plt.show()

# %%
sub = cv2.subtract(img3, img4)

# %%
if cv2.waitKey(0) & 0xff == 27:
    cv2.destroyAllWindows()

# %%
plt.imshow(sub)
plt.show()

# %%
img5 = cv2.imread('/content/5.png')
img6 = cv2.imread('/content/6.png')

# %%
plt.imshow(img5)
plt.show()

# %%
plt.imshow(img6)
plt.show()

# %%
result_image = cv2.multiply(img5, img6)

# %%
plt.imshow(result_image)
plt.show()

# %%
img7 = cv2.imread('/content/peakpx222222.jpg')

# %%
plt.imshow(img7)
plt.show()

# %%
gray_image = cv2.cvtColor(img7, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_image)
plt.show()
